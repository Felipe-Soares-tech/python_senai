# %% [markdown]
# # Análise exploratoria de top10 do catalogo Netiflix
#
# Analisaremos a seguir uma base de dados do catalogo Netflix, com intuito de entender quais produtos do seu catalogo alcançaram o top 10 mais assistidos da plataforma para fins de estudos e aprendizado da bibliotecas "pandas".

# %%
# instalando e importando o pandas
# pip install pandas
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'd:\Users\ALUNO\Desktop\python_senai\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# importando pandas
import pandas as pd

# %%
# tornando variavel em um dataframe
df_netflix = pd.read_csv("netflix daily top 10.csv", sep=",")

# %%
# vizualizando as primeiras 5
df_netflix.head()
# Out:
#         As of  Rank Year to Date Rank Last Week Rank  \
# 0  2020-04-01     1                 1              1
# 1  2020-04-01     2                 2              -
# 2  2020-04-01     3                 3              2
# 3  2020-04-01     4                 4              -
# 4  2020-04-01     5                 5              4
#
#                           Title     Type Netflix Exclusive  \
# 0  Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                         Ozark  TV Show               Yes
# 2                  All American  TV Show               NaN
# 3                  Blood Father    Movie               NaN
# 4                  The Platform    Movie               Yes
#
#   Netflix Release Date  Days In Top 10  Viewership Score
# 0         Mar 20, 2020               9                90
# 1         Jul 21, 2017               5                45
# 2         Mar 28, 2019               9                76
# ...

# %%
#vizualizando as 5 ultimas
df_netflix.tail()

# %%
#vizualiza tudo
display(df_netflix)
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  \
# 0     2020-04-01     1                 1              1
# 1     2020-04-01     2                 2              -
# 2     2020-04-01     3                 3              2
# 3     2020-04-01     4                 4              -
# 4     2020-04-01     5                 5              4
# ...          ...   ...               ...            ...
# 7095  2022-03-11     6                 5              1
# 7096  2022-03-11     7                 7              2
# 7097  2022-03-11     8                 8              -
# 7098  2022-03-11     9                 9              7
# 7099  2022-03-11    10                10              -
#
#                              Title     Type Netflix Exclusive  \
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show               NaN
# ...

# %%
# informacoes individuais de cada coluna do deframe, com base em seu tipo, nome quantidade de registros nulos
df_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7100 entries, 0 to 7099
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   As of                 7100 non-null   object
#  1   Rank                  7100 non-null   int64
#  2   Year to Date Rank     7100 non-null   object
#  3   Last Week Rank        7100 non-null   object
#  4   Title                 7100 non-null   object
#  5   Type                  7100 non-null   object
#  6   Netflix Exclusive     4599 non-null   object
#  7   Netflix Release Date  7100 non-null   object
#  8   Days In Top 10        7100 non-null   int64
#  9   Viewership Score      7100 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 554.8+ KB

# %%
#informa os tipos das colunas        
df_netflix.dtypes
# Out:
# As of                   object
# Rank                     int64
# Year to Date Rank       object
# Last Week Rank          object
# Title                   object
# Type                    object
# Netflix Exclusive       object
# Netflix Release Date    object
# Days In Top 10           int64
# Viewership Score         int64
# dtype: object

# %%
#verificamos uma coluna especifica de uma dataframe e analisamos a quantidade de nulos presentes
df_netflix["Netflix Exclusive"].isnull().sum()
# Out:
# np.int64(2501)

# %%
df_netflix["Title"].value_counts()
# Out:
# Title
# Cocomelon                       428
# Ozark                            85
# Cobra Kai                        81
# Manifest                         80
# The Queenâs Gambit             73
#                                ...
# The Lucky One                     1
# Fistful of Vengeance              1
# Dark Shadows                      1
# Scary Stories to Tell in th…      1
# Chosen                            1
# Name: count, Length: 645, dtype: int64

# %%
df_netflix.describe()
# Out:
#               Rank  Days In Top 10  Viewership Score
# count  7100.000000     7100.000000       7100.000000
# mean      5.500000       24.123662        122.790141
# std       2.872484       58.473789        213.861642
# min       1.000000        1.000000          1.000000
# 25%       3.000000        3.000000         19.000000
# 50%       5.500000        7.000000         50.000000
# 75%       8.000000       18.000000        128.000000
# max      10.000000      428.000000       1474.000000

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'd:\Users\ALUNO\Desktop\python_senai\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
df_netflix.plot(kind='box',figsize=(13,4),subplots=True)
# Out:
# Rank                   Axes(0.125,0.11;0.227941x0.77)
# Days In Top 10      Axes(0.398529,0.11;0.227941x0.77)
# Viewership Score    Axes(0.672059,0.11;0.227941x0.77)
# dtype: object

# %%
df_netflix.hist()
# Out:
# array([[<Axes: title={'center': 'Rank'}>,
#         <Axes: title={'center': 'Days In Top 10'}>],
#        [<Axes: title={'center': 'Viewership Score'}>, <Axes: >]],
#       dtype=object)

# %%
def noaply(exclusive):
    if exclusive != "Yes":
        return "No"
    return exclusive

# %%
# df_tratado = [df_netflix["Netflix Exclusive"].apply(noaply)]
df_netflix["Netflix Exclusive"] = df_netflix["Netflix Exclusive"].apply(noaply)

# %%
display(df_netflix)
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  \
# 0     2020-04-01     1                 1              1
# 1     2020-04-01     2                 2              -
# 2     2020-04-01     3                 3              2
# 3     2020-04-01     4                 4              -
# 4     2020-04-01     5                 5              4
# ...          ...   ...               ...            ...
# 7095  2022-03-11     6                 5              1
# 7096  2022-03-11     7                 7              2
# 7097  2022-03-11     8                 8              -
# 7098  2022-03-11     9                 9              7
# 7099  2022-03-11    10                10              -
#
#                              Title     Type Netflix Exclusive  \
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show                No
# ...

# %%
df_netflix.drop("Last Week Rank", axis=1)
# Out:
#            As of  Rank Year to Date Rank                         Title  \
# 0     2020-04-01     1                 1  Tiger King: Murder, Mayhem …
# 1     2020-04-01     2                 2                         Ozark
# 2     2020-04-01     3                 3                  All American
# 3     2020-04-01     4                 4                  Blood Father
# 4     2020-04-01     5                 5                  The Platform
# ...          ...   ...               ...                           ...
# 7095  2022-03-11     6                 5           Worst Roommate Ever
# 7096  2022-03-11     7                 7             Vikings: Valhalla
# 7097  2022-03-11     8                 8                       Shooter
# 7098  2022-03-11     9                 9                       Shrek 2
# 7099  2022-03-11    10                10                         Shrek
#
#          Type Netflix Exclusive Netflix Release Date  Days In Top 10  \
# ...
